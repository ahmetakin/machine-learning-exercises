# %% [markdown]
# # Train Test Ayırma verileri
# ## Bu egzersizde verilerin train ve test verisetleri olarak ayrılması incelenecek

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("iris.csv")

# %%
df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
#
# [3 rows x 5 columns]

# %%
#x = df.iloc[:,:-1].values
#VEYA Y zaten target sütunu olduğu için o sütunu düşürebiliriz
x = df.drop('target', axis=1)  #
print(x)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#y = df.iloc[:,-1].values
#y içinde direk target sütun seçilebilir
y = df['target']
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
print(x_train)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 22                 4.6               3.6                1.0               0.2
# 15                 5.7               4.4                1.5               0.4
# 65                 6.7               3.1                4.4               1.4
# 11                 4.8               3.4                1.6               0.2
# 42                 4.4               3.2                1.3               0.2
# ..                 ...               ...                ...               ...
# 71                 6.1               2.8                4.0               1.3
# 106                4.9               2.5                4.5               1.7
# 14                 5.8               4.0                1.2               0.2
# 92                 5.8               2.6                4.0               1.2
# 102                7.1               3.0                5.9               2.1
#
# [120 rows x 4 columns]

# %%
print(x_test)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
# 78                 6.0               2.9                4.5               1.5
# 76                 6.8               2.8                4.8               1.4
# 31                 5.4               3.4                1.5               0.4
# 64                 5.6               2.9                3.6               1.3
# 141                6.9               3.1                5.1               2.3
# 68                 6.2               2.2                4.5               1.5
# 82                 5.8               2.7                3.9               1.2
# 110                6.5               3.2                5.1               2.0
# ...

# %%
print(y_train)
# Out:
# 22     0
# 15     0
# 65     1
# 11     0
# 42     0
#       ..
# 71     1
# 106    2
# 14     0
# 92     1
# 102    2
# Name: target, Length: 120, dtype: int64

# %%
print(y_test)
# Out:
# 73     1
# 18     0
# 118    2
# 78     1
# 76     1
# 31     0
# 64     1
# 141    2
# 68     1
# 82     1
# 110    2
# 12     0
# 36     0
# 9      0
# 19     0
# 56     1
# 104    2
# 69     1
# 55     1
# 132    2
# 29     0
# 127    2
# 26     0
# 128    2
# 131    2
# 145    2
# 108    2
# 143    2
# 45     0
# 30     0
# Name: target, dtype: int64
